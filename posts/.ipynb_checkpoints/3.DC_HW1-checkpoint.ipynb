# %% [raw]
# ---
# title: "3. DC HW1"
# author: "이상민"
# date: "04/05/2025"
# ---

# %% [markdown]
# ## **1. 제공된 코드를 이용하여 아래를 시행하시오.**
# ### **1) 평균이 3인 정규분포, 포아송분포, 이항분포, 감마분포, 지수분포에서 각 500개의 표본을 생성해서 5개의 히스토그램을 그리고 5개의 표본평균을 구하시오. 모수가 여러 개인 경우 모수의 값을 조정해서 평균을 3으로 하시오**

# %% [markdown]
# ### 1. 정규분포

# %% [markdown]
# `-` 표본추출, 히스토그램
#
# * mean = 3 으로 지정

# %%
normal_random <- rnorm(n = 500, mean = 3)
hist(normal_random)
# Out:
# Plot with title “Histogram of normal_random”

# %% [markdown]
# `-` 표본평균

# %%
mean(normal_random)
# Out:
# [1] 3.002564

# %% [markdown]
# ### 2. 포아송분포

# %% [markdown]
# `-` 표본추출, 히스토그램
#
# * 포아송 분포에서 $E(X) = \lambda$ 이므로 $\lambda$ = 3으로 지정

# %%
poisson_random <- rpois(n = 500, lambda = 3)
hist(poisson_random)
# Out:
# Plot with title “Histogram of poisson_random”

# %% [markdown]
# `-` 표본평균

# %%
mean(poisson_random)
# Out:
# [1] 2.874

# %% [markdown]
# ### 3. 이항분포

# %% [markdown]
# `-` 표본추출, 히스토그램
#
# * 이항분포에서 $E(X) = np$ 이므로 `size` : `n`, `prob` = `p` 에 대응되므로 평균을 10 X 0.3 = 3으로 설정

# %%
binomial_random <- rbinom(n = 500, size = 10, prob = 0.3)
hist(binomial_random, breaks = seq(-0.5, 10.5, by = 1))
# Out:
# Plot with title “Histogram of binomial_random”

# %% [markdown]
# `-` 표본평균

# %%
mean(binomial_random)
# Out:
# [1] 3.106

# %% [markdown]
# ### 4. 감마분포

# %% [markdown]
# `-` 표본추출, 히스토그램
#
# * $GAM(\alpha,\beta)$ 에서 `shape` : $\alpha$,  `rate` : $\frac{1}{\beta}$ 에 대응
# * 감마분포에서 $E(X) =$ $\alpha$ X $\beta$
# * 1(shape) X 3(=1/rate) = 3

# %%
gamma_random = rgamma(n=500,shape=1,rate=1/3)
hist(gamma_random)
# Out:
# Plot with title “Histogram of gamma_random”

# %%
mean(gamma_random)
# Out:
# [1] 2.865978

# %% [markdown]
# ### 5. 지수분포

# %% [markdown]
# `-` 표본추출, 히스토그램
#
# * 지수분포에서 $E(X)= \frac{1}{\lambda}$
# * rate= $\lambda$ 이므로 3(=1/rate)=3

# %%
exponential_random <- rexp(n = 500, rate = 1/3)
hist(exponential_random)
# Out:
# Plot with title “Histogram of exponential_random”

# %% [markdown]
# `-` 표본평균

# %%
mean(exponential_random)
# Out:
# [1] 3.002938

# %% [markdown]
# ### **2) (추가) 이항분포, 정규분포, 감마분포에서 평균을 3, 분산을 5로 하여 각 500 개의 표본을 생성해서 3개의 히스토그램과 표본평균 그리고 표본 분산을 구하시오**

# %% [markdown]
# ### 1. 이항분포

# %% [markdown]
# `-` 표본추출, 히스토그램
#
# * 이항분포에서 $E(X) = np$ 이고
# * 이항분포에서 $Var(X) = np(1-p)$ 임
# * np=3이어야하고 np(1-p)=5여야하므로 (1-p)=5/3 $\to$ 불가능한데? 잠시 pass
# * `size` : `n`, `prob` = `p` 에 대응되므로 ...

# %%
binomial_random <- rbinom(n = 500, size = 10, prob = 0.3)
hist(binomial_random, breaks = seq(-0.5, 10.5, by = 1))

# %%
mean(binomial_random)

# %% [markdown]
# ### 2. 정규분포
